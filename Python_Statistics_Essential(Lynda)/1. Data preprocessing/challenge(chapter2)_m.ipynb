# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
df=pd.read_csv('tb.csv')
df.head()
# Out:
#   country  year  m04  m514  m014  m1524  m2534  m3544  m4554  m5564  ...  f04  \
# 0      AD  1989  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 1      AD  1990  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 2      AD  1991  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 3      AD  1992  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 4      AD  1993  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
#
#    f514  f014  f1524  f2534  f3544  f4554  f5564  f65  fu
# 0   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 1   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 2   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 3   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 4   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'm04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
#        'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
#        'f3544', 'f4554', 'f5564', 'f65', 'fu'],
#       dtype='object')

# %%
melt= df.melt(['country', 'year'],['m04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
       'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
       'f3544', 'f4554', 'f5564', 'f65', 'fu'], 'sexage', 'cases')
melt.head()
# Out:
#   country  year sexage  cases
# 0      AD  1989    m04    NaN
# 1      AD  1990    m04    NaN
# 2      AD  1991    m04    NaN
# 3      AD  1992    m04    NaN
# 4      AD  1993    m04    NaN

# %%
melt['sex']= melt['sexage'].str.slice(0,1)
melt['age']=melt['sexage'].str.slice(1)
melt.head()
# Out:
#   country  year sexage  cases sex age
# 0      AD  1989    m04    NaN   m  04
# 1      AD  1990    m04    NaN   m  04
# 2      AD  1991    m04    NaN   m  04
# 3      AD  1992    m04    NaN   m  04
# 4      AD  1993    m04    NaN   m  04

# %%
for i, row in melt.iterrows():
    temp = row['age']
    if temp == '65':
        melt.at[i, 'age'] = '65+'
    elif len(temp) == 2:
        melt.at[i, 'age'] = temp[0:1] + '-' + temp[1:]
    elif len(temp) == 3:
        melt.at[i, 'age'] = temp[0:1] + '-' + temp[1:]
    elif len(temp) == 4:
        melt.at[i, 'age'] = temp[0:2] + '-' + temp[2:]
    elif temp == 'u':
        melt.at[i, 'age'] = np.nan
    else:
        print('Value in row {} was not changed'.format(i))

# %%
melt.head()
# Out:
#   country  year sexage  cases sex  age
# 0      AD  1989    m04    NaN   m  0-4
# 1      AD  1990    m04    NaN   m  0-4
# 2      AD  1991    m04    NaN   m  0-4
# 3      AD  1992    m04    NaN   m  0-4
# 4      AD  1993    m04    NaN   m  0-4

# %%
final = melt.dropna(subset=['cases'])

# %%
final = final.drop('sexage', axis=1)
final.head()
# Out:
#    country  year  cases sex  age
# 15      AD  2005    0.0   m  0-4
# 16      AD  2006    0.0   m  0-4
# 18      AD  2008    0.0   m  0-4
# 42      AE  2006    0.0   m  0-4
# 43      AE  2007    0.0   m  0-4

# %%
final.sort_values(['country','year','age','sex'])
final.head()
# Out:
#    country  year  cases sex  age
# 15      AD  2005    0.0   m  0-4
# 16      AD  2006    0.0   m  0-4
# 18      AD  2008    0.0   m  0-4
# 42      AE  2006    0.0   m  0-4
# 43      AE  2007    0.0   m  0-4

# %%
final.to_csv('final_m.csv',index=False)
